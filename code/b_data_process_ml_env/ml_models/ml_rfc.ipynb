# %%
from scipy.stats import uniform
import datetime

import pandas as pd
import numpy as np

import json
import os

import seaborn as sns
import matplotlib.pyplot as plt

from sktime.datatypes import convert_to

from sklearn.utils import class_weight


from sktime.transformations.series.exponent import ExponentTransformer, SqrtTransformer
from sktime.transformations.series.cos import CosineTransformer

from sktime.transformations.series.summarize import SummaryTransformer
from sktime.transformations.series.augmenter import WhiteNoiseAugmenter

from sklearn.model_selection import KFold, StratifiedKFold, RandomizedSearchCV, GridSearchCV
from sklearn.preprocessing import LabelEncoder

# Model import
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier

from matplotlib import pyplot as plt

import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# <span style="font-size:1.5em;">Settings and pre-execution analysis functions</span>

# %%
DESIGN_NAME = "FabScalar"
DESIGN = DESIGN_NAME.lower()
REPO_PATH = "/mnt/shared-scratch/Hu_J/minh.luu/github/vcdiag_fabscalar"

DATA_ANALYSIS_PATH = f"{REPO_PATH}/data_analysis"
CONFIG_PATH = f"{REPO_PATH}/configs/{DESIGN}.json"
FINAL_BUG_DATA_PATH_TRAIN = f"{DATA_ANALYSIS_PATH}/data/final_data/train/"
FINAL_BUG_DATA_PATH_TEST = f"{DATA_ANALYSIS_PATH}/data/final_data/test/"

# %%
with open(CONFIG_PATH, "r") as f:
    config = json.load(f)
sim_and_extract_config = config["sim_and_extract"]
extract_config = sim_and_extract_config["extract"]
BEFORE_FAILURE_TIMEFRAME = extract_config["line_limit"]
label_mapping = config["general"]["label_mapping"]

# %%
# Count the frequency of each label in the train label.csv
def count_label_frequency(label_file_path):
    label_freq = {}
    with open(label_file_path, 'r') as f:
        for line in f:
            label = line.split(',')[1].strip()
            if label not in label_freq:
                label_freq[label] = 1
            else:
                label_freq[label] += 1
    return label_freq


display(count_label_frequency(FINAL_BUG_DATA_PATH_TRAIN + "label.csv"))
display(count_label_frequency(FINAL_BUG_DATA_PATH_TEST + "label.csv"))
# Out:
# {'FECHONE': 744,
#  'FECHWO': 774,
#  'DECODE': 651,
#  'DISP': 382,
#  'EXEC': 630,
#  'INSBUF': 450,
#  'ISSUE': 460,
#  'LSU': 558,
#  'MAPABLE': 528,
#  'REGREAD': 641,
#  'REIRE': 411,
#  'RENAME': 387}
# {'FECHONE': 94,
#  'FECHWO': 126,
#  'DECODE': 120,
#  'DISP': 50,
#  'EXEC': 93,
#  'INSBUF': 70,
#  'ISSUE': 87,
#  'LSU': 75,
#  'MAPABLE': 91,
#  'REGREAD': 113,
#  'REIRE': 48,
#  'RENAME': 63}

# %% [markdown]
# <span style="font-size:1.5em;">Support classes and functions</span>

# %%
class StopExecution(Exception):
    def _render_traceback_(self):
        return []

# %% [markdown]
# <span style="font-size:1.5em;">Training</span>

# %% [markdown]
# <span style="font-size:1em;">Data import and preprocess</span>

# %%
# Read training data from csv
X_train = pd.read_csv(f"{FINAL_BUG_DATA_PATH_TRAIN}/data.csv")
label_train_df = pd.read_csv(
    f"{FINAL_BUG_DATA_PATH_TRAIN}/label.csv", index_col=0, header=None)
y_train = label_train_df.to_numpy().flatten()

# Read testing data from csv
X_test = pd.read_csv(f"{FINAL_BUG_DATA_PATH_TEST}/data.csv")

label_test_df = pd.read_csv(
    f"{FINAL_BUG_DATA_PATH_TEST}/label.csv", index_col=0, header=None)
y_test = label_test_df.to_numpy().flatten()

# Drop column "instances" for both training and testing data
X_train = X_train.drop(columns=["instances"])
X_test = X_test.drop(columns=["instances"])

X_train_original = X_train.copy()
X_test_original = X_test.copy()
y_train_original = label_train_df.to_numpy().flatten()
y_test_original = label_test_df.to_numpy().flatten()

# %%
X_train = X_train_original.copy()
X_test = X_test_original.copy()
y_train = y_train_original.copy()
y_test = y_test_original.copy()

print(f"Label mapping: {label_mapping}")

# Convert the labels to the corresponding values in the label_mapping
for i in range(len(y_train)):
    y_train[i] = label_mapping[y_train[i]]
for i in range(len(y_test)):
    y_test[i] = label_mapping[y_test[i]]

# cap the training dataset at 200 samples per class
X_train = X_train.copy()
y_train = y_train.copy()
X_train["label"] = y_train
X_train = X_train.groupby("label").head(3000)
y_train = X_train["label"]
X_train = X_train.drop(columns=["label"])

label_freq_train = {}
for label in y_train:
    if label not in label_freq_train:
        label_freq_train[label] = 1
    else:
        label_freq_train[label] += 1
        
label_freq_test = {}
for label in y_test:
    if label not in label_freq_test:
        label_freq_test[label] = 1
    else:
        label_freq_test[label] += 1
       
display(label_freq_train)
display(label_freq_test)
# Out:
# Label mapping: {'FECHONE': 'FetchStage1', 'FECHWO': 'FetchStage2', 'DECODE': 'Decode', 'INSBUF': 'InstructionBuffer', 'RENAME': 'Rename', 'DISP': 'Dispatch', 'ISSUE': 'IssueQueue', 'REGREAD': 'RegRead', 'EXEC': 'Execution', 'LSU': 'LoadStoreUnit', 'REIRE': 'Retire', 'MAPABLE': 'ArchMapTable'}
# {'FetchStage1': 744,
#  'FetchStage2': 774,
#  'Decode': 651,
#  'Dispatch': 382,
#  'Execution': 630,
#  'InstructionBuffer': 450,
#  'IssueQueue': 460,
#  'LoadStoreUnit': 558,
#  'ArchMapTable': 528,
#  'RegRead': 641,
#  'Retire': 411,
#  'Rename': 387}
# {'FetchStage1': 94,
#  'FetchStage2': 126,
#  'Decode': 120,
#  'Dispatch': 50,
#  'Execution': 93,
#  'InstructionBuffer': 70,
#  'IssueQueue': 87,
#  'LoadStoreUnit': 75,
#  'ArchMapTable': 91,
#  'RegRead': 113,
#  'Retire': 48,
#  'Rename': 63}

# %%
# convert all labels to float
le = LabelEncoder()
y_train_float = le.fit_transform(y_train)
y_test_float = le.transform(y_test)

# prep stats
classes = np.unique(y_train_float)
n_classes = len(classes)
class_weights = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=classes,
    y=y_train_float
)

display(f"Weights: {class_weights}")
class_weights = {i: class_weights[i] for i in range(n_classes)}
max_delta_step = 1
# Out:
# 'Weights: [1.04419192 0.8469022  1.44328098 0.87513228 0.74103943 0.71231697\n 1.22518519 1.19855072 0.98805257 0.8601144  1.42463394 1.34144363]'

# %%
columns_to_drop = [name for name in X_train.columns if any([name.endswith(suffix) for suffix in ["_kurt"]])]

X_train = X_train.drop(columns=columns_to_drop)
X_test = X_test.drop(columns=columns_to_drop)

# %%
display(X_train.head())
display(X_train.shape)
display(y_train)
# Out:
#    1__0.1  1__0.5  1__0.9  1__0.25  1__0.75  1__max      1__mean  1__min  \
# 0   120.0  1000.0  1880.0    450.0   1550.0  2100.0  1005.111111     0.0
# 1   440.0  2600.0  4760.0   1250.0   3950.0  5300.0  2602.110092     0.0
# 2    94.0   850.0  1610.0    375.0   1325.0  1800.0   855.897436     0.0
# 3   130.0  1050.0  1970.0    475.0   1625.0  2200.0  1054.893617     0.0
# 4    76.0   700.0  1340.0    300.0   1100.0  1500.0   706.969697     0.0
#
#         1__std  2__0.1  ...  4860__std  4861__0.1  4861__0.5  4861__0.9  \
# 0   648.535491     1.0  ...  24.784791       34.0       34.0       34.0
# 1  1576.949160     1.0  ...  16.409773       34.0       34.0       34.0
# 2   560.782902     1.0  ...  26.591248       34.0       34.0       34.0
# 3   677.725969     1.0  ...  24.279535       34.0       34.0       34.0
# 4   472.655298     1.0  ...  28.834395       34.0       34.0       34.0
#
#    4861__0.25  4861__0.75  4861__max  4861__mean  4861__min  4861__std
# 0        34.0        34.0      120.0   37.822222       34.0  17.923181
# 1        34.0        34.0      120.0   35.577982       34.0  11.595253
# 2        34.0        34.0      120.0   38.410256       34.0  19.217204
# 3        34.0        34.0      120.0   37.659574       34.0  17.546555
# 4        34.0        34.0      120.0   39.212121       34.0  20.838302
#
# [5 rows x 43749 columns]
# (6616, 43749)
# 0       FetchStage1
# 1       FetchStage1
# 2       FetchStage1
# 3       FetchStage1
# 4       FetchStage1
#            ...
# 6611         Rename
# 6612         Rename
# 6613         Rename
# 6614         Rename
# 6615         Rename
# Name: label, Length: 6616, dtype: object

# %% [markdown]
# <span style="font-size:1em;">ML model definition and training</span>

# %%
# Define the RF parameters
rf_params = {
    'n_estimators': 50, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_depth': 50, 'bootstrap': False, 'class_weight': class_weights
}

model = RandomForestClassifier(**rf_params)

print(model)

model.fit(X_train, y_train_float)
# Out:
# RandomForestClassifier(bootstrap=False,
#                        class_weight={0: np.float64(1.0441919191919191),
#                                      1: np.float64(0.8469022017409115),
#                                      2: np.float64(1.443280977312391),
#                                      3: np.float64(0.8751322751322751),
#                                      4: np.float64(0.7410394265232975),
#                                      5: np.float64(0.7123169681309216),
#                                      6: np.float64(1.2251851851851852),
#                                      7: np.float64(1.1985507246376812),
#                                      8: np.float64(0.98805256869773),
#                                      9: np.float64(0.860114404576183),
#                                      10: np.float64(1.4246339362618432),
#                                      11: np.float64(1.3414436334144364)},
#                        max_depth=50, min_samples_split=10, n_estimators=50)
# RandomForestClassifier(bootstrap=False,
#                        class_weight={0: np.float64(1.0441919191919191),
#                                      1: np.float64(0.8469022017409115),
#                                      2: np.float64(1.443280977312391),
#                                      3: np.float64(0.8751322751322751),
#                                      4: np.float64(0.7410394265232975),
#                                      5: np.float64(0.7123169681309216),
#                                      6: np.float64(1.2251851851851852),
#                                      7: np.float64(1.1985507246376812),
#                                      8: np.float64(0.98805256869773),
#                                      9: np.float64(0.860114404576183),
#                                      10: np.float64(1.4246339362618432),
#                                      11: np.float64(1.3414436334144364)},
#                        max_depth=50, min_samples_split=10, n_estimators=50)

# %% [markdown]
# <span style="font-size:1.5em;">Testing</span>

# %%
y_pred_bin = model.predict(X_test)
y_pred = le.inverse_transform(y_pred_bin)
y_pred_proba = model.predict_proba(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, top_k_accuracy_score

acs = accuracy_score(y_test, y_pred)
cm = confusion_matrix(y_test, y_pred)
# Normalize the confusion matrix
cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis] * 100
cr = classification_report(y_test, y_pred, digits=4, output_dict=True)
top3_acs = top_k_accuracy_score(y_test, y_pred_proba, k=3 if n_classes > 3 else n_classes)

print(acs)
print(top3_acs)

# Convert integer labels for the confusion matrix to string labels
labels = np.unique(y_train)

# Plot confusion matrix with seaborn
plt.figure(figsize=(10, 7))
ax = sns.heatmap(cm, annot=True, fmt=".1f", cmap='Blues',
                 xticklabels=labels, yticklabels=labels)
# Add % sign to heatmap
for t in ax.texts:
    t.set_text(t.get_text() + "%")
plt.xticks(ticks=np.arange(len(labels)) + 0.5, labels=labels)
plt.yticks(ticks=np.arange(len(labels)) + 0.5, labels=labels)
plt.xlabel('Predicted')
plt.ylabel('Truth')

ax.xaxis.tick_top()
ax.xaxis.set_label_position('top')
ax.tick_params(axis='x', rotation=25)

ax.yaxis.tick_left()
ax.yaxis.set_label_position('left')
ax.tick_params(axis='y', rotation=25)


# Save the confusion matrix and classification report to a file
# Create a folder to store the logs if it does not exist
if not os.path.exists(f"{DATA_ANALYSIS_PATH}/logs/ml_metrics_logs"):
    os.makedirs(f"{DATA_ANALYSIS_PATH}/logs/ml_metrics_logs")
plt.savefig(f"{DATA_ANALYSIS_PATH}/logs/ml_metrics_logs/cm_rfc_{BEFORE_FAILURE_TIMEFRAME}_{datetime.datetime.now().strftime('%Y-%m-%d_%H-%M-%S')}.png", bbox_inches='tight', dpi=150)
# round to 4 decimal places for better readability
cr_df = pd.DataFrame(cr).transpose().round(4)
cr_df.to_csv(f"{DATA_ANALYSIS_PATH}/logs/ml_metrics_logs/cr_rfc_{BEFORE_FAILURE_TIMEFRAME}_{datetime.datetime.now().strftime('%Y-%m-%d_%H-%M-%S')}.csv")
# Out:
# 0.7116504854368932
# 0.858252427184466

# %%
# Create a DataFrame to display the probabilities in a more descriptive way
df_prob = pd.DataFrame(y_pred_proba, columns=[f'{class_name}_prob' for class_name in le.classes_])
df_prob['True_Label'] = y_test
df_prob['Predicted_Label'] = y_pred

# Inverse transform the labels
# df_prob['True_Label'] = le.inverse_transform(df_prob['True_Label'])
# df_prob['Predicted_Label'] = le.inverse_transform(df_prob['Predicted_Label'])

# Show only misclassified instances
df_prob = df_prob[df_prob['True_Label'] != df_prob['Predicted_Label']]

# Print the entire DataFrame
pd.set_option('display.max_rows', None)
display(df_prob)
# Out:
#       ArchMapTable_prob  Decode_prob  Dispatch_prob  Execution_prob  \
# 1              0.000000     0.036148       0.059281        0.075702
# 92             0.028907     0.015240       0.086596        0.137496
# 102            0.000000     0.000000       0.000000        0.000000
# 106            0.025429     0.006345       0.015783        0.548186
# 112            0.025429     0.006345       0.015783        0.548186
# 113            0.000000     0.000000       0.000000        0.020000
# 114            0.000000     0.000000       0.000000        0.000000
# 117            0.000000     0.000000       0.000000        0.020000
# 150            0.000000     0.000000       0.053297        0.015930
# 166            0.000113     0.031960       0.044984        0.542639
# 167            0.000000     0.081987       0.006624        0.025286
# 168            0.000000     0.042749       0.002567        0.037162
# 171            0.000000     0.067273       0.006624        0.040000
# 185            0.000000     0.000000       0.000000        0.020000
# 186            0.000000     0.000000       0.000000        0.000000
# 187            0.000000     0.000000       0.017496        0.021270
# 189            0.000000     0.000000       0.000000        0.020000
# 208            0.004385     0.024429       0.047483        0.368619
# 212            0.000113     0.018660       0.126367        0.026448
# 213            0.002225     0.008709       0.011124        0.141640
# 226            0.020000     0.014867       0.000000        0.156106
# 227            0.000113     0.198838       0.047780        0.259286
# 228            0.004137     0.013271       0.185182        0.046052
# 229            0.000113     0.028432       0.068449        0.023522
# 230            0.006868     0.021912       0.085556        0.076394
# 231            0.006331     0.141083       0.103029        0.029698
# 232            0.025634     0.256265       0.359963        0.000000
# 332          0.002733            0.002229      0.514482     0.026296
# 333          0.029957            0.001369      0.661964     0.001561
# 336          0.272721            0.000000      0.103004     0.056049
# 344          0.709111            0.037522      0.000000     0.159772
# 345          0.012914            0.018326      0.130804     0.065697
# 346          0.637062            0.034550      0.001637     0.287935
# 347          0.045578            0.063139      0.689333     0.002184
# 348          0.003281            0.013929      0.712632     0.000623
# 349          0.047225            0.004336      0.164332     0.124794
# 350          0.041235            0.062923      0.569620     0.000000
# 355          0.049105            0.045894      0.047529     0.041889
# 356          0.003058            0.000000      0.125130     0.003815
# ...
# 228      0.277823             Decode             Retire
# 229      0.044659             Decode            RegRead
# 230      0.091746             Decode            RegRead
# 231      0.192480             Decode            RegRead
# 232      0.000000             Decode           Dispatch
# 233      0.024145             Decode             Rename
# 234      0.005376             Decode             Rename
# 238      0.011836             Decode        FetchStage2
# 239      0.009736             Decode        FetchStage2
# 240      0.289581             Decode             Retire
# 241      0.004640             Decode          Execution
# 242      0.023981             Decode            RegRead
# 243      0.014800             Decode  InstructionBuffer
# 256      0.000000             Decode  InstructionBuffer
# 257      0.011517             Decode  InstructionBuffer
# 258      0.025779             Decode  InstructionBuffer
# 259      0.002596             Decode  InstructionBuffer
# 260      0.000000             Decode  InstructionBuffer
# 261      0.010724             Decode  InstructionBuffer
# 268      0.011450             Decode          Execution
# 269      0.053311             Decode          Execution
# 270      0.268124             Decode             Retire
# 271      0.079104             Decode          Execution
# 272      0.058812             Decode            RegRead
# 273      0.195581             Decode             Retire
# 274      0.006602             Decode        FetchStage2
# 275      0.011363             Decode        FetchStage2
# 276      0.041013             Decode        FetchStage2
# 277      0.041023             Decode        FetchStage2
# 279      0.003323             Decode        FetchStage2
# 283      0.007629             Decode        FetchStage2
# 286      0.023193             Decode        FetchStage1
# 287      0.020803             Decode      LoadStoreUnit
# 288      0.043791             Decode             Rename
# 289      0.020000             Decode         IssueQueue
# 293      0.020000             Decode         IssueQueue
# 295      0.041702             Decode             Rename
# 296      0.000000             Decode       ArchMapTable
# 297      0.020191             Decode             Rename
# 298      0.162582             Decode          Execution
# 299      0.000000             Decode          Execution
# 300      0.015743             Decode       ArchMapTable
# 301      0.022747             Decode            RegRead
# 302      0.097592             Decode          Execution
# 303      0.004473             Decode      LoadStoreUnit
# 304      0.012178             Decode             Rename
# 305      0.007456             Decode          Execution
# 306      0.003747             Decode          Execution
# 313      0.042547             Decode        FetchStage1
# 314      0.027456             Decode          Execution
# 315      0.000000             Decode        FetchStage1
# 319      0.000000             Decode          Execution
# 328      0.104273             Decode            RegRead
# 329      0.099484             Decode            RegRead
# 330      0.331895             Decode             Retire
# 331      0.160124             Decode            RegRead
# 332      0.113352             Decode            RegRead
# 333      0.064782             Decode            RegRead
# 336      0.011328             Decode         IssueQueue
# 344      0.032285           Dispatch         IssueQueue
# 345      0.109882           Dispatch          Execution
# 346      0.023235           Dispatch         IssueQueue
# 347      0.129268           Dispatch            RegRead
# 348      0.188094           Dispatch            RegRead
# 349      0.256456           Dispatch             Retire
# 350      0.121966           Dispatch            RegRead
# 355      0.118042           Dispatch        FetchStage2
# 356      0.156446           Dispatch          Execution
# 358      0.191189           Dispatch            RegRead
# 370      0.000000           Dispatch      LoadStoreUnit
# 382      0.017727           Dispatch  InstructionBuffer
# 383      0.033250           Dispatch  InstructionBuffer
# 384      0.007860           Dispatch  InstructionBuffer
# 388      0.000000           Dispatch      LoadStoreUnit
# 401      0.008093          Execution             Rename
# 402      0.034659          Execution        FetchStage1
# 403      0.073563          Execution        FetchStage1
# 410      0.009840          Execution            RegRead
# 414      0.008093          Execution             Rename
# 415      0.034659          Execution        FetchStage1
# 416      0.073563          Execution        FetchStage1
# 423      0.150084          Execution           Dispatch
# 426      0.021597          Execution        FetchStage1
# 427      0.004302          Execution        FetchStage1
# 428      0.004273          Execution       ArchMapTable
# 433      0.020000          Execution             Rename
# 434      0.036485          Execution        FetchStage1
# 436      0.051693          Execution        FetchStage1
# 442      0.051693          Execution        FetchStage1
# 443      0.017603          Execution        FetchStage1
# 448      0.003671          Execution       ArchMapTable
# 450      0.043555          Execution            RegRead
# 457      0.000000          Execution       ArchMapTable
# 458      0.084730          Execution            RegRead
# 459      0.001230          Execution             Rename
# 460      0.001849          Execution            RegRead
# 461      0.023776          Execution             Rename
# 469      0.007414          Execution            RegRead
# 474      0.289089          Execution             Retire
# 476      0.317340          Execution             Retire
# 477      0.039980          Execution       ArchMapTable
# 479      0.007309          Execution             Rename
# 480      0.000000          Execution            RegRead
# 483      0.002598  InstructionBuffer             Decode
# 488      0.096827  InstructionBuffer             Decode
# 500      0.283954  InstructionBuffer           Dispatch
# 501      0.108693  InstructionBuffer            RegRead
# 502      0.238657  InstructionBuffer             Retire
# 503      0.131452  InstructionBuffer            RegRead
# 504      0.024005  InstructionBuffer             Decode
# 505      0.013110  InstructionBuffer           Dispatch
# 506      0.003587  InstructionBuffer             Decode
# 507      0.578374  InstructionBuffer             Retire
# 508      0.002804  InstructionBuffer             Decode
# 509      0.000000  InstructionBuffer             Decode
# 511      0.021323  InstructionBuffer         IssueQueue
# 544      0.000000  InstructionBuffer           Dispatch
# 545      0.002344  InstructionBuffer           Dispatch
# 546      0.000000  InstructionBuffer           Dispatch
# 547      0.000000  InstructionBuffer           Dispatch
# 548      0.008529  InstructionBuffer           Dispatch
# 549      0.004197  InstructionBuffer           Dispatch
# 553      0.021989         IssueQueue      LoadStoreUnit
# 554      0.068000         IssueQueue             Rename
# 555      0.021951         IssueQueue            RegRead
# 558      0.008166         IssueQueue            RegRead
# 559      0.436395         IssueQueue             Retire
# 561      0.019956         IssueQueue        FetchStage1
# 600      0.023657         IssueQueue      LoadStoreUnit
# 601      0.017975         IssueQueue             Rename
# 602      0.000000         IssueQueue            RegRead
# 606      0.003750         IssueQueue            RegRead
# 607      0.005657         IssueQueue      LoadStoreUnit
# 608      0.004348         IssueQueue            RegRead
# 610      0.057246         IssueQueue            RegRead
# 631      0.099150         IssueQueue          Execution
# 632      0.130692         IssueQueue            RegRead
# 633      0.018754         IssueQueue             Rename
# 674      0.009207      LoadStoreUnit           Dispatch
# 676      0.063086      LoadStoreUnit        FetchStage1
# 679      0.100209      LoadStoreUnit             Rename
# 681      0.022280      LoadStoreUnit       ArchMapTable
# 682      0.000000      LoadStoreUnit           Dispatch
# 684      0.018650      LoadStoreUnit           Dispatch
# 685      0.137039      LoadStoreUnit           Dispatch
# 693      0.648064      LoadStoreUnit             Retire
# 694      0.926376      LoadStoreUnit             Retire
# 695      0.034951      LoadStoreUnit            RegRead
# 703      0.106539      LoadStoreUnit             Rename
# 704      0.022280      LoadStoreUnit       ArchMapTable
# 707      0.002106      LoadStoreUnit       ArchMapTable
# 708      0.599977      LoadStoreUnit             Retire
# 709      0.579348      LoadStoreUnit             Retire
# 710      0.740470      LoadStoreUnit             Retire
# 711      0.926376      LoadStoreUnit             Retire
# 713      0.056619      LoadStoreUnit            RegRead
# 714      0.569679      LoadStoreUnit             Retire
# 715      0.006402       ArchMapTable             Rename
# 716      0.003106       ArchMapTable             Rename
# 719      0.026299       ArchMapTable             Rename
# 720      0.003216       ArchMapTable          Execution
# 721      0.018827       ArchMapTable      LoadStoreUnit
# 724      0.055090       ArchMapTable             Rename
# 726      0.072422       ArchMapTable            RegRead
# 728      0.055815       ArchMapTable            RegRead
# 738      0.150084       ArchMapTable           Dispatch
# 748      0.012325       ArchMapTable             Rename
# 751      0.048688       ArchMapTable             Rename
# 755      0.000000       ArchMapTable             Rename
# 756      0.006016       ArchMapTable             Rename
# 758      0.043637       ArchMapTable        FetchStage1
# 759      0.010098       ArchMapTable             Rename
# 761      0.026191       ArchMapTable          Execution
# 763      0.107820       ArchMapTable             Rename
# 785      0.003106       ArchMapTable             Rename
# 786      0.004778       ArchMapTable             Rename
# 788      0.000000       ArchMapTable      LoadStoreUnit
# 790      0.012325       ArchMapTable             Rename
# 791      0.065058       ArchMapTable             Rename
# 794      0.048688       ArchMapTable             Rename
# 806      0.005551            RegRead             Decode
# 807      0.053171            RegRead         IssueQueue
# 808      0.142656            RegRead             Decode
# 809      0.005759            RegRead             Decode
# 810      0.107900            RegRead         IssueQueue
# 811      0.057052            RegRead         IssueQueue
# 813      0.150084            RegRead           Dispatch
# 819      0.002697            RegRead          Execution
# 822      0.029691            RegRead          Execution
# 828      0.006576            RegRead           Dispatch
# 829      0.622104            RegRead             Retire
# 830      0.533046            RegRead             Retire
# 831      0.602566            RegRead             Retire
# 832      0.662104            RegRead             Retire
# 833      0.555759            RegRead             Retire
# 834      0.642104            RegRead             Retire
# 835      0.023715            RegRead          Execution
# 837      0.044094            RegRead          Execution
# 838      0.000000            RegRead          Execution
# 839      0.007075            RegRead      LoadStoreUnit
# 847      0.001230            RegRead          Execution
# 848      0.002697            RegRead          Execution
# 849      0.000000            RegRead             Rename
# 851      0.000000            RegRead       ArchMapTable
# 858      0.015661            RegRead           Dispatch
# 859      0.000000            RegRead             Rename
# 861      0.012565            RegRead             Rename
# 862      0.001230            RegRead           Dispatch
# 863      0.009720            RegRead          Execution
# 866      0.014019            RegRead             Rename
# 869      0.066045            RegRead       ArchMapTable
# 871      0.000000            RegRead       ArchMapTable
# 873      0.002928            RegRead        FetchStage2
# 874      0.014458            RegRead       ArchMapTable
# 879      0.012687            RegRead      LoadStoreUnit
# 899      0.006812            RegRead          Execution
# 900      0.006812            RegRead          Execution
# 901      0.698962            RegRead             Retire
# 902      0.609473            RegRead             Retire
# 903      0.682566            RegRead             Retire
# 904      0.742104            RegRead             Retire
# 905      0.633451            RegRead             Retire
# 906      0.700142            RegRead             Retire
# 908      0.150084            RegRead           Dispatch
# 911      0.058143            RegRead      LoadStoreUnit
# 917      0.017270            RegRead      LoadStoreUnit
# 922      0.181026             Retire      LoadStoreUnit
# 923      0.003840             Retire          Execution
# 924      0.429414             Retire          Execution
# 925      0.219937             Retire             Decode
# 926      0.207987             Retire             Decode
# 927      0.057087             Retire       ArchMapTable
# 929      0.000000             Retire             Rename
# 935      0.283525             Retire  InstructionBuffer
# 946      0.020000             Retire        FetchStage1
# 954      0.000000             Retire  InstructionBuffer
# 955      0.020000             Retire        FetchStage1
# 956      0.008133             Retire      LoadStoreUnit
# 960      0.104133             Retire            RegRead
# 961      0.016326             Retire            RegRead
# 963      0.153982             Retire          Execution
# 964      0.020000             Retire             Decode
# 965      0.020000             Retire             Decode
# 966      0.000000             Retire             Decode
# 968      0.081289             Rename            RegRead
# 969      0.001230             Rename          Execution
# 970      0.001230             Rename          Execution
# 975      0.063787             Rename       ArchMapTable
# 976      0.009207             Rename       ArchMapTable
# 977      0.090417             Rename       ArchMapTable
# 979      0.275021             Rename             Retire
# 980      0.084826             Rename            RegRead
# 981      0.011180             Rename      LoadStoreUnit
# 983      0.004395             Rename          Execution
# 984      0.057352             Rename            RegRead
# 988      0.026835             Rename            RegRead
# 990      0.029366             Rename       ArchMapTable
# 991      0.345132             Rename             Retire
# 994      0.019604             Rename      LoadStoreUnit
# 995      0.003165             Rename          Execution
# 996      0.178264             Rename         IssueQueue
# 997      0.290541             Rename            RegRead
# 998      0.027058             Rename            RegRead
# 999      0.005327             Rename         IssueQueue
# 1000     0.014593             Rename         IssueQueue
# 1012     0.000000             Rename          Execution
# 1013     0.150084             Rename           Dispatch
# 1016     0.000000             Rename        FetchStage2
# 1017     0.023715             Rename          Execution
# 1019     0.133109             Rename         IssueQueue
# 1021     0.005141             Rename            RegRead
# 1022     0.016101             Rename          Execution
# 1025     0.010484             Rename          Execution
# 1028     0.000000             Rename       ArchMapTable
# 1029     0.000000             Rename          Execution

# %%
# Graph multi-class ROC curve
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc
from numpy import interp
from itertools import cycle

n_classes = len(count_label_frequency(FINAL_BUG_DATA_PATH_TRAIN + "label.csv"))
class_names = le.classes_
y_test_bin = label_binarize(y_test, classes=class_names)
y_pred_bin = y_pred_proba

fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], y_pred_bin[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
    
    
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])
    
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

plt.figure(figsize=(10, 5))
plt.plot(fpr["macro"], tpr["macro"], label="Macro-average ROC curve (area = {:.4f})".format(roc_auc["macro"]), color="navy", linestyle=":")
colors = cycle(["aqua", "darkorange", "cornflowerblue", "red", "green", "purple", "yellow", "brown", "pink", "gray"])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2, label="{0} ROC curve (area = {1:.4f})".format(class_names[i], roc_auc[i]))
    
plt.plot([0, 1], [0, 1], "k--")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title(f"Multi-class ROC curve (RFC) - {DESIGN_NAME}")
plt.legend(loc="lower right")

# Save the ROC curve
plt.savefig(f"{DATA_ANALYSIS_PATH}/logs/ml_metrics_logs/roc_rfc_{BEFORE_FAILURE_TIMEFRAME}_{datetime.datetime.now().strftime('%Y-%m-%d_%H-%M-%S')}.png", bbox_inches='tight', dpi=150)

plt.show()
