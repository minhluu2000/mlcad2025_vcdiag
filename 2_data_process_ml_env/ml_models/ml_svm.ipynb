# %%
from scipy.stats import uniform
import datetime

import pandas as pd
import numpy as np

import json
import os

import seaborn as sns
import matplotlib.pyplot as plt

from sktime.datatypes import convert_to

from sktime.dists_kernels import AggrDist, ScipyDist
from sklearn.utils import class_weight
from sktime.datasets import load_unit_test

from sklearn.model_selection import KFold, RandomizedSearchCV, GridSearchCV, cross_val_score
from sklearn.preprocessing import LabelEncoder
from sklearn.svm import SVC


from matplotlib import pyplot as plt

import warnings
warnings.filterwarnings(action='ignore')

from scipy.stats import uniform

from sklearnex import patch_sklearn 

patch_sklearn()
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/uxlfoundation/scikit-learn-intelex)

# %% [markdown]
# <span style="font-size:1.5em;">Settings and pre-execution analysis functions</span>

# %%
DESIGN_NAME = "FabScalar"
DESIGN = DESIGN_NAME.lower()
REPO_PATH = "/mnt/shared-scratch/Hu_J/minh.luu/github/vcdiag_fabscalar"

DATA_ANALYSIS_PATH = f"{REPO_PATH}/data_analysis"
CONFIG_PATH = f"{REPO_PATH}/configs/{DESIGN}.json"
FINAL_BUG_DATA_PATH_TRAIN = f"{DATA_ANALYSIS_PATH}/data/final_data/train/"
FINAL_BUG_DATA_PATH_TEST = f"{DATA_ANALYSIS_PATH}/data/final_data/test/"

# %%
with open(CONFIG_PATH, "r") as f:
    config = json.load(f)
sim_and_extract_config = config["sim_and_extract"]
extract_config = sim_and_extract_config["extract"]
BEFORE_FAILURE_TIMEFRAME = extract_config["line_limit"]
label_mapping = config["general"]["label_mapping"]

# %%
# Count the frequency of each label in the train label.csv
def count_label_frequency(label_file_path):
    label_freq = {}
    with open(label_file_path, 'r') as f:
        for line in f:
            label = line.split(',')[1].strip()
            if label not in label_freq:
                label_freq[label] = 1
            else:
                label_freq[label] += 1
    return label_freq


display(count_label_frequency(FINAL_BUG_DATA_PATH_TRAIN + "label.csv"))
display(count_label_frequency(FINAL_BUG_DATA_PATH_TEST + "label.csv"))
# Out:
# {'FECHONE': 744,
#  'FECHWO': 774,
#  'DECODE': 651,
#  'DISP': 382,
#  'EXEC': 630,
#  'INSBUF': 450,
#  'ISSUE': 460,
#  'LSU': 558,
#  'MAPABLE': 528,
#  'REGREAD': 641,
#  'REIRE': 411,
#  'RENAME': 387}
# {'FECHONE': 94,
#  'FECHWO': 126,
#  'DECODE': 120,
#  'DISP': 50,
#  'EXEC': 93,
#  'INSBUF': 70,
#  'ISSUE': 87,
#  'LSU': 75,
#  'MAPABLE': 91,
#  'REGREAD': 113,
#  'REIRE': 48,
#  'RENAME': 63}

# %% [markdown]
# <span style="font-size:1.5em;">Support classes and functions</span>

# %%
class StopExecution(Exception):
    def _render_traceback_(self):
        return []

# %% [markdown]
# <span style="font-size:1.5em;">Training</span>

# %% [markdown]
# <span style="font-size:1em;">Data import and preprocess</span>

# %%
# Read training data from csv
X_train = pd.read_csv(f"{FINAL_BUG_DATA_PATH_TRAIN}/data.csv")
label_train_df = pd.read_csv(
    f"{FINAL_BUG_DATA_PATH_TRAIN}/label.csv", index_col=0, header=None)
y_train = label_train_df.to_numpy().flatten()

# Read testing data from csv
X_test = pd.read_csv(f"{FINAL_BUG_DATA_PATH_TEST}/data.csv")

label_test_df = pd.read_csv(
    f"{FINAL_BUG_DATA_PATH_TEST}/label.csv", index_col=0, header=None)
y_test = label_test_df.to_numpy().flatten()

# Drop column "instances" for both training and testing data
X_train = X_train.drop(columns=["instances"])
X_test = X_test.drop(columns=["instances"])

X_train_original = X_train.copy()
X_test_original = X_test.copy()
y_train_original = label_train_df.to_numpy().flatten()
y_test_original = label_test_df.to_numpy().flatten()

# %%
X_train = X_train_original.copy()
X_test = X_test_original.copy()
y_train = y_train_original.copy()
y_test = y_test_original.copy()

print(f"Label mapping: {label_mapping}")

# Convert the labels to the corresponding values in the label_mapping
for i in range(len(y_train)):
    y_train[i] = label_mapping[y_train[i]]
for i in range(len(y_test)):
    y_test[i] = label_mapping[y_test[i]]

# cap the training dataset at 200 samples per class
X_train = X_train.copy()
y_train = y_train.copy()
X_train["label"] = y_train
X_train = X_train.groupby("label").head(3000)
y_train = X_train["label"]
X_train = X_train.drop(columns=["label"])

label_freq_train = {}
for label in y_train:
    if label not in label_freq_train:
        label_freq_train[label] = 1
    else:
        label_freq_train[label] += 1
        
label_freq_test = {}
for label in y_test:
    if label not in label_freq_test:
        label_freq_test[label] = 1
    else:
        label_freq_test[label] += 1
       
display(label_freq_train)
display(label_freq_test)
# Out:
# Label mapping: {'FECHONE': 'FetchStage1', 'FECHWO': 'FetchStage2', 'DECODE': 'Decode', 'INSBUF': 'InstructionBuffer', 'RENAME': 'Rename', 'DISP': 'Dispatch', 'ISSUE': 'IssueQueue', 'REGREAD': 'RegRead', 'EXEC': 'Execution', 'LSU': 'LoadStoreUnit', 'REIRE': 'Retire', 'MAPABLE': 'ArchMapTable'}
# {'FetchStage1': 744,
#  'FetchStage2': 774,
#  'Decode': 651,
#  'Dispatch': 382,
#  'Execution': 630,
#  'InstructionBuffer': 450,
#  'IssueQueue': 460,
#  'LoadStoreUnit': 558,
#  'ArchMapTable': 528,
#  'RegRead': 641,
#  'Retire': 411,
#  'Rename': 387}
# {'FetchStage1': 94,
#  'FetchStage2': 126,
#  'Decode': 120,
#  'Dispatch': 50,
#  'Execution': 93,
#  'InstructionBuffer': 70,
#  'IssueQueue': 87,
#  'LoadStoreUnit': 75,
#  'ArchMapTable': 91,
#  'RegRead': 113,
#  'Retire': 48,
#  'Rename': 63}

# %%
# convert all labels to float
le = LabelEncoder()
y_train_float = le.fit_transform(y_train)
y_test_float = le.transform(y_test)

# prep stats
classes = np.unique(y_train_float)
n_classes = len(classes)
class_weights = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=classes,
    y=y_train_float
)

display(f"Weights: {class_weights}")
class_weights = {i: class_weights[i] for i in range(n_classes)}
max_delta_step = 1
# Out:
# 'Weights: [1.04419192 0.8469022  1.44328098 0.87513228 0.74103943 0.71231697\n 1.22518519 1.19855072 0.98805257 0.8601144  1.42463394 1.34144363]'

# %%
columns_to_drop = [name for name in X_train.columns if any([name.endswith(suffix) for suffix in ["_kurt"]])]

X_train = X_train.drop(columns=columns_to_drop)
X_test = X_test.drop(columns=columns_to_drop)

# %%
display(X_train.head())
display(X_train.shape)
display(y_train)
# Out:
#    1__0.1  1__0.5  1__0.9  1__0.25  1__0.75  1__max      1__mean  1__min  \
# 0   120.0  1000.0  1880.0    450.0   1550.0  2100.0  1005.111111     0.0
# 1   440.0  2600.0  4760.0   1250.0   3950.0  5300.0  2602.110092     0.0
# 2    94.0   850.0  1610.0    375.0   1325.0  1800.0   855.897436     0.0
# 3   130.0  1050.0  1970.0    475.0   1625.0  2200.0  1054.893617     0.0
# 4    76.0   700.0  1340.0    300.0   1100.0  1500.0   706.969697     0.0
#
#         1__std  2__0.1  ...  4860__std  4861__0.1  4861__0.5  4861__0.9  \
# 0   648.535491     1.0  ...  24.784791       34.0       34.0       34.0
# 1  1576.949160     1.0  ...  16.409773       34.0       34.0       34.0
# 2   560.782902     1.0  ...  26.591248       34.0       34.0       34.0
# 3   677.725969     1.0  ...  24.279535       34.0       34.0       34.0
# 4   472.655298     1.0  ...  28.834395       34.0       34.0       34.0
#
#    4861__0.25  4861__0.75  4861__max  4861__mean  4861__min  4861__std
# 0        34.0        34.0      120.0   37.822222       34.0  17.923181
# 1        34.0        34.0      120.0   35.577982       34.0  11.595253
# 2        34.0        34.0      120.0   38.410256       34.0  19.217204
# 3        34.0        34.0      120.0   37.659574       34.0  17.546555
# 4        34.0        34.0      120.0   39.212121       34.0  20.838302
#
# [5 rows x 43749 columns]
# (6616, 43749)
# 0       FetchStage1
# 1       FetchStage1
# 2       FetchStage1
# 3       FetchStage1
# 4       FetchStage1
#            ...
# 6611         Rename
# 6612         Rename
# 6613         Rename
# 6614         Rename
# 6615         Rename
# Name: label, Length: 6616, dtype: object

# %% [markdown]
# <span style="font-size:1em;">ML model definition and training</span>

# %%
# SVC parameters
# svc_params = {
#     'gamma': 0.1, 'C': 50
# }

# Define the SVC classifier
model = SVC(probability=True)

model.fit(X_train, y_train_float)
# Out:
# SVC(probability=True)

# %% [markdown]
# <span style="font-size:1.5em;">Testing</span>

# %%
y_pred_bin = model.predict(X_test)
y_pred = le.inverse_transform(y_pred_bin)
y_pred_proba = model.predict_proba(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, top_k_accuracy_score

acs = accuracy_score(y_test, y_pred)
cm = confusion_matrix(y_test, y_pred)
# Normalize the confusion matrix
cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis] * 100
cr = classification_report(y_test, y_pred, digits=4, output_dict=True)
top3_acs = top_k_accuracy_score(y_test, y_pred_proba, k=3 if n_classes > 3 else n_classes)

print(acs)
print(top3_acs)

# Convert integer labels for the confusion matrix to string labels
labels = np.unique(y_train)

# Plot confusion matrix with seaborn
plt.figure(figsize=(10, 7))
ax = sns.heatmap(cm, annot=True, fmt=".1f", cmap='Blues',
                 xticklabels=labels, yticklabels=labels)
# Add % sign to heatmap
for t in ax.texts:
    t.set_text(t.get_text() + "%")
plt.xticks(ticks=np.arange(len(labels)) + 0.5, labels=labels)
plt.yticks(ticks=np.arange(len(labels)) + 0.5, labels=labels)
plt.xlabel('Predicted')
plt.ylabel('Truth')

ax.xaxis.tick_top()
ax.xaxis.set_label_position('top')
ax.tick_params(axis='x', rotation=25)

ax.yaxis.tick_left()
ax.yaxis.set_label_position('left')
ax.tick_params(axis='y', rotation=25)


# Save the confusion matrix and classification report to a file
# Create a folder to store the logs if it does not exist
if not os.path.exists(f"{DATA_ANALYSIS_PATH}/logs/ml_metrics_logs"):
    os.makedirs(f"{DATA_ANALYSIS_PATH}/logs/ml_metrics_logs")
plt.savefig(f"{DATA_ANALYSIS_PATH}/logs/ml_metrics_logs/cm_svm_{BEFORE_FAILURE_TIMEFRAME}_{datetime.datetime.now().strftime('%Y-%m-%d_%H-%M-%S')}.png", bbox_inches='tight', dpi=150)
# round to 4 decimal places for better readability
cr_df = pd.DataFrame(cr).transpose().round(4)
cr_df.to_csv(f"{DATA_ANALYSIS_PATH}/logs/ml_metrics_logs/cr_svm_{BEFORE_FAILURE_TIMEFRAME}_{datetime.datetime.now().strftime('%Y-%m-%d_%H-%M-%S')}.csv")
# Out:
# 0.47378640776699027
# 0.7446601941747573

# %%
# Create a DataFrame to display the probabilities in a more descriptive way
df_prob = pd.DataFrame(y_pred_proba, columns=[f'{class_name}_prob' for class_name in le.classes_])
df_prob['True_Label'] = y_test
df_prob['Predicted_Label'] = y_pred

# Inverse transform the labels
# df_prob['True_Label'] = le.inverse_transform(df_prob['True_Label'])
# df_prob['Predicted_Label'] = le.inverse_transform(df_prob['Predicted_Label'])

# Show only misclassified instances
df_prob = df_prob[df_prob['True_Label'] != df_prob['Predicted_Label']]

# Print the entire DataFrame
pd.set_option('display.max_rows', None)
display(df_prob)
# Out:
#       ArchMapTable_prob  Decode_prob  Dispatch_prob  Execution_prob  \
# 1              0.032784     0.007146       0.033193        0.067903
# 80             0.007143     0.024829       0.025796        0.276884
# 81             0.074794     0.488024       0.009081        0.035358
# 89             0.071411     0.015654       0.085658        0.021775
# 92             0.229996     0.010176       0.138022        0.053773
# 96             0.013638     0.065407       0.040933        0.057741
# 98             0.023575     0.119789       0.034776        0.057402
# 106            0.010646     0.082061       0.028527        0.261372
# 107            0.020970     0.324827       0.017463        0.179665
# 109            0.013874     0.367976       0.017490        0.077380
# 112            0.010646     0.082061       0.028527        0.261372
# 118            0.005815     0.013191       0.032649        0.155124
# 119            0.026044     0.214423       0.019981        0.290929
# 120            0.010938     0.059383       0.039894        0.062246
# 121            0.021361     0.166783       0.020212        0.099641
# 122            0.016520     0.061378       0.026927        0.057796
# 123            0.022327     0.136620       0.018881        0.440390
# 139            0.012130     0.106824       0.016240        0.032105
# 146            0.022159     0.034730       0.023002        0.126817
# 148            0.014728     0.130802       0.027590        0.192757
# 151            0.005690     0.231715       0.022530        0.137626
# 154            0.007862     0.052710       0.015835        0.065043
# 157            0.015057     0.069351       0.020108        0.049339
# 158            0.023586     0.071396       0.032630        0.093022
# 159            0.022141     0.152428       0.022759        0.110130
# 162            0.009011     0.032097       0.029764        0.052458
# 163            0.015378     0.069237       0.019739        0.047051
# 164            0.028712     0.076117       0.035390        0.107538
# 165            0.014059     0.099235       0.023584        0.266707
# 166            0.007691     0.053479       0.041128        0.351627
# 167            0.027272     0.103290       0.046436        0.113859
# 168            0.051503     0.118940       0.040143        0.094039
# 169            0.018386     0.178984       0.030972        0.051969
# 171            0.031531     0.099242       0.050132        0.157505
# 172            0.010651     0.008760       0.015694        0.027108
# 174            0.009543     0.014884       0.025524        0.131870
# 175            0.006165     0.027261       0.035503        0.301585
# 176            0.006042     0.018843       0.043991        0.042619
# 178            0.008479     0.009187       0.022150        0.365884
# 179            0.018999     0.256371       0.018250        0.251354
# 607      0.018280         IssueQueue          Execution
# 608      0.041716         IssueQueue          Execution
# 609      0.025066         IssueQueue        FetchStage1
# 610      0.046223         IssueQueue          Execution
# 611      0.043722         IssueQueue          Execution
# 620      0.415566         IssueQueue             Retire
# 621      0.289321         IssueQueue             Retire
# 630      0.715108         IssueQueue             Retire
# 631      0.048271         IssueQueue          Execution
# 632      0.162860         IssueQueue            RegRead
# 633      0.036495         IssueQueue             Rename
# 636      0.065303         IssueQueue             Decode
# 644      0.009485      LoadStoreUnit          Execution
# 645      0.052002      LoadStoreUnit            RegRead
# 646      0.032828      LoadStoreUnit          Execution
# 647      0.060599      LoadStoreUnit       ArchMapTable
# 648      0.059394      LoadStoreUnit       ArchMapTable
# 649      0.060599      LoadStoreUnit       ArchMapTable
# 650      0.060597      LoadStoreUnit       ArchMapTable
# 651      0.131496      LoadStoreUnit         IssueQueue
# 652      0.393962      LoadStoreUnit             Retire
# 654      0.677923      LoadStoreUnit             Retire
# 660      0.060599      LoadStoreUnit       ArchMapTable
# 661      0.057330      LoadStoreUnit       ArchMapTable
# 662      0.070989      LoadStoreUnit       ArchMapTable
# 663      0.060597      LoadStoreUnit       ArchMapTable
# 664      0.047533      LoadStoreUnit            RegRead
# 665      0.052090      LoadStoreUnit            RegRead
# 666      0.038859      LoadStoreUnit            RegRead
# 668      0.038018      LoadStoreUnit            RegRead
# 669      0.119683      LoadStoreUnit         IssueQueue
# 670      0.492906      LoadStoreUnit             Retire
# 671      0.132370      LoadStoreUnit         IssueQueue
# 672      0.364823      LoadStoreUnit             Retire
# 673      0.041674      LoadStoreUnit         IssueQueue
# 674      0.014835      LoadStoreUnit       ArchMapTable
# 676      0.031257      LoadStoreUnit        FetchStage1
# 677      0.009468      LoadStoreUnit          Execution
# 678      0.051522      LoadStoreUnit            RegRead
# 679      0.038810      LoadStoreUnit            RegRead
# 681      0.012571      LoadStoreUnit          Execution
# 682      0.014921      LoadStoreUnit       ArchMapTable
# 684      0.017396      LoadStoreUnit       ArchMapTable
# 685      0.018883      LoadStoreUnit            RegRead
# 689      0.128010      LoadStoreUnit         IssueQueue
# 690      0.077082      LoadStoreUnit         IssueQueue
# 692      0.031675      LoadStoreUnit         IssueQueue
# 693      0.632610      LoadStoreUnit             Retire
# 694      0.645032      LoadStoreUnit             Retire
# 695      0.029482      LoadStoreUnit            RegRead
# 697      0.009621      LoadStoreUnit          Execution
# 698      0.052002      LoadStoreUnit            RegRead
# 699      0.032828      LoadStoreUnit          Execution
# 700      0.047532      LoadStoreUnit            RegRead
# 701      0.009468      LoadStoreUnit          Execution
# 702      0.051522      LoadStoreUnit            RegRead
# 703      0.038810      LoadStoreUnit            RegRead
# 704      0.012571      LoadStoreUnit          Execution
# 705      0.131759      LoadStoreUnit         IssueQueue
# 706      0.350485      LoadStoreUnit             Retire
# 707      0.018748      LoadStoreUnit       ArchMapTable
# 708      0.614415      LoadStoreUnit             Retire
# 709      0.631506      LoadStoreUnit             Retire
# 710      0.424102      LoadStoreUnit             Retire
# 711      0.645032      LoadStoreUnit             Retire
# 712      0.047391      LoadStoreUnit            RegRead
# 713      0.033376      LoadStoreUnit            RegRead
# 714      0.376956      LoadStoreUnit             Retire
# 715      0.022335       ArchMapTable             Rename
# 718      0.025858       ArchMapTable      LoadStoreUnit
# 719      0.022564       ArchMapTable      LoadStoreUnit
# 720      0.018120       ArchMapTable          Execution
# 721      0.025566       ArchMapTable      LoadStoreUnit
# 722      0.025451       ArchMapTable             Rename
# 724      0.025884       ArchMapTable        FetchStage1
# 725      0.022497       ArchMapTable          Execution
# 726      0.012713       ArchMapTable        FetchStage1
# 727      0.012244       ArchMapTable          Execution
# 728      0.022150       ArchMapTable      LoadStoreUnit
# 735      0.025451       ArchMapTable             Rename
# 736      0.020436       ArchMapTable        FetchStage1
# 737      0.021051       ArchMapTable      LoadStoreUnit
# 738      0.018883       ArchMapTable            RegRead
# 739      0.041237       ArchMapTable            RegRead
# 741      0.013843       ArchMapTable        FetchStage1
# 742      0.023107       ArchMapTable      LoadStoreUnit
# 751      0.027758       ArchMapTable        FetchStage1
# 752      0.049109       ArchMapTable            RegRead
# 755      0.024735       ArchMapTable             Rename
# 756      0.017007       ArchMapTable             Rename
# 758      0.020631       ArchMapTable      LoadStoreUnit
# 759      0.022225       ArchMapTable      LoadStoreUnit
# 760      0.018802       ArchMapTable             Rename
# 761      0.018660       ArchMapTable          Execution
# 762      0.018438       ArchMapTable      LoadStoreUnit
# 763      0.027443       ArchMapTable        FetchStage1
# 764      0.049109       ArchMapTable            RegRead
# 766      0.041237       ArchMapTable            RegRead
# 769      0.056868       ArchMapTable             Decode
# 770      0.049109       ArchMapTable            RegRead
# 772      0.041237       ArchMapTable            RegRead
# 775      0.049109       ArchMapTable            RegRead
# 777      0.041237       ArchMapTable            RegRead
# 781      0.013866       ArchMapTable      LoadStoreUnit
# 784      0.014288       ArchMapTable      LoadStoreUnit
# 788      0.016499       ArchMapTable      LoadStoreUnit
# 791      0.020209       ArchMapTable        FetchStage1
# 794      0.027758       ArchMapTable        FetchStage1
# 806      0.121909            RegRead         IssueQueue
# 807      0.265959            RegRead         IssueQueue
# 808      0.168616            RegRead         IssueQueue
# 809      0.040235            RegRead         IssueQueue
# 810      0.125509            RegRead      LoadStoreUnit
# 811      0.084882            RegRead         IssueQueue
# 812      0.014858            RegRead          Execution
# 814      0.011444            RegRead          Execution
# 817      0.012333            RegRead          Execution
# 818      0.574229            RegRead             Retire
# 819      0.018481            RegRead          Execution
# 821      0.030888            RegRead          Execution
# 822      0.039031            RegRead          Execution
# 823      0.014812            RegRead             Rename
# 824      0.012466            RegRead          Execution
# 825      0.010530            RegRead       ArchMapTable
# 826      0.015397            RegRead       ArchMapTable
# 827      0.017469            RegRead      LoadStoreUnit
# 829      0.625017            RegRead             Retire
# 830      0.737909            RegRead             Retire
# 831      0.423709            RegRead             Retire
# 832      0.670564            RegRead             Retire
# 833      0.617067            RegRead             Retire
# 834      0.661359            RegRead             Retire
# 835      0.040171            RegRead          Execution
# 837      0.013800            RegRead          Execution
# 838      0.028450            RegRead          Execution
# 839      0.014557            RegRead          Execution
# 846      0.012332            RegRead          Execution
# 848      0.018481            RegRead          Execution
# 849      0.018303            RegRead       ArchMapTable
# 851      0.012010            RegRead      LoadStoreUnit
# 853      0.023848            RegRead         IssueQueue
# 855      0.400097            RegRead             Retire
# 856      0.540439            RegRead             Retire
# 857      0.348541            RegRead         IssueQueue
# 858      0.013847            RegRead          Execution
# 859      0.010174            RegRead          Execution
# 860      0.015959            RegRead          Execution
# 861      0.019389            RegRead       ArchMapTable
# 863      0.013855            RegRead          Execution
# 864      0.572907            RegRead             Retire
# 865      0.048802            RegRead         IssueQueue
# 866      0.019711            RegRead             Rename
# 868      0.354036            RegRead             Retire
# 869      0.021053            RegRead       ArchMapTable
# 871      0.009389            RegRead          Execution
# 873      0.016309            RegRead      LoadStoreUnit
# 874      0.013289            RegRead          Execution
# 879      0.018890            RegRead      LoadStoreUnit
# 881      0.013802            RegRead          Execution
# 883      0.021253            RegRead          Execution
# 886      0.037620            RegRead          Execution
# 887      0.013802            RegRead          Execution
# 889      0.021253            RegRead          Execution
# 892      0.037620            RegRead          Execution
# 899      0.031007            RegRead          Execution
# 900      0.037017            RegRead          Execution
# 901      0.625043            RegRead             Retire
# 902      0.737904            RegRead             Retire
# 903      0.423747            RegRead             Retire
# 904      0.670559            RegRead             Retire
# 905      0.617071            RegRead             Retire
# 906      0.661352            RegRead             Retire
# 911      0.018861            RegRead          Execution
# 917      0.031345            RegRead      LoadStoreUnit
# 919      0.057507             Retire          Execution
# 921      0.042846             Retire          Execution
# 922      0.089794             Retire           Dispatch
# 923      0.016892             Retire      LoadStoreUnit
# 924      0.034258             Retire          Execution
# 925      0.019168             Retire        FetchStage2
# 926      0.019185             Retire        FetchStage2
# 927      0.019741             Retire       ArchMapTable
# 928      0.135470             Retire  InstructionBuffer
# 929      0.021414             Retire       ArchMapTable
# 930      0.046819             Retire        FetchStage2
# 931      0.046826             Retire        FetchStage2
# 932      0.053680             Retire        FetchStage2
# 933      0.063267             Retire        FetchStage2
# 934      0.046825             Retire        FetchStage2
# 935      0.010720             Retire             Decode
# 936      0.029313             Retire             Decode
# 946      0.028487             Retire        FetchStage1
# 953      0.194866             Retire  InstructionBuffer
# 954      0.017148             Retire            RegRead
# 955      0.028487             Retire        FetchStage1
# 956      0.011412             Retire        FetchStage1
# 960      0.021766             Retire            RegRead
# 961      0.027374             Retire            RegRead
# 963      0.059889             Retire           Dispatch
# 964      0.009841             Retire  InstructionBuffer
# 965      0.010847             Retire  InstructionBuffer
# 966      0.011250             Retire  InstructionBuffer
# 967      0.014082             Rename          Execution
# 968      0.015106             Rename            RegRead
# 969      0.013671             Rename          Execution
# 970      0.021584             Rename            RegRead
# 972      0.009810             Rename       ArchMapTable
# 973      0.012097             Rename          Execution
# 974      0.014347             Rename            RegRead
# 975      0.020272             Rename       ArchMapTable
# 976      0.011896             Rename          Execution
# 977      0.020272             Rename       ArchMapTable
# 978      0.011683             Rename      LoadStoreUnit
# 979      0.038692             Rename  InstructionBuffer
# 980      0.083296             Rename  InstructionBuffer
# 981      0.021252             Rename      LoadStoreUnit
# 982      0.031302             Rename        FetchStage1
# 983      0.014352             Rename          Execution
# 984      0.027963             Rename            RegRead
# 987      0.017337             Rename       ArchMapTable
# 988      0.027755             Rename           Dispatch
# 989      0.060446             Rename  InstructionBuffer
# 990      0.034543             Rename  InstructionBuffer
# 991      0.052138             Rename  InstructionBuffer
# 992      0.115520             Rename  InstructionBuffer
# 993      0.017209             Rename          Execution
# 994      0.016550             Rename            RegRead
# 995      0.014907             Rename          Execution
# 996      0.018909             Rename            RegRead
# 997      0.046884             Rename            RegRead
# 998      0.014747             Rename            RegRead
# 1000     0.017810             Rename            RegRead
# 1001     0.514636             Rename             Retire
# 1002     0.039140             Rename         IssueQueue
# 1003     0.140680             Rename         IssueQueue
# 1004     0.076288             Rename         IssueQueue
# 1005     0.037028             Rename           Dispatch
# 1006     0.065331             Rename         IssueQueue
# 1007     0.071235             Rename         IssueQueue
# 1008     0.027666             Rename          Execution
# 1009     0.049709             Rename          Execution
# 1010     0.039482             Rename          Execution
# 1011     0.063342             Rename            RegRead
# 1012     0.014974             Rename          Execution
# 1013     0.018883             Rename            RegRead
# 1014     0.013276             Rename          Execution
# 1015     0.017188             Rename       ArchMapTable
# 1016     0.018497             Rename      LoadStoreUnit
# 1017     0.040171             Rename          Execution
# 1018     0.011554             Rename          Execution
# 1019     0.029393             Rename          Execution
# 1020     0.017326             Rename       ArchMapTable
# 1021     0.032863             Rename            RegRead
# 1022     0.015491             Rename          Execution
# 1023     0.011969             Rename          Execution
# 1025     0.033501             Rename          Execution
# 1026     0.026642             Rename      LoadStoreUnit
# 1027     0.019989             Rename      LoadStoreUnit
# 1028     0.009883             Rename          Execution
# 1029     0.017148             Rename            RegRead

# %%
# Graph multi-class ROC curve
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc
from numpy import interp
from itertools import cycle

n_classes = len(count_label_frequency(FINAL_BUG_DATA_PATH_TRAIN + "label.csv"))
class_names = le.classes_
y_test_bin = label_binarize(y_test, classes=class_names)
y_pred_bin = y_pred_proba

fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], y_pred_bin[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
    
    
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])
    
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

plt.figure(figsize=(10, 5))
plt.plot(fpr["macro"], tpr["macro"], label="Macro-average ROC curve (area = {:.4f})".format(roc_auc["macro"]), color="navy", linestyle=":")
colors = cycle(["aqua", "darkorange", "cornflowerblue", "red", "green", "purple", "yellow", "brown", "pink", "gray"])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2, label="{0} ROC curve (area = {1:.4f})".format(class_names[i], roc_auc[i]))
    
plt.plot([0, 1], [0, 1], "k--")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title(f"Multi-class ROC curve (SVM) - {DESIGN_NAME}")
plt.legend(loc="lower right")

# Save the ROC curve
plt.savefig(f"{DATA_ANALYSIS_PATH}/logs/ml_metrics_logs/roc_svm_{BEFORE_FAILURE_TIMEFRAME}_{datetime.datetime.now().strftime('%Y-%m-%d_%H-%M-%S')}.png", bbox_inches='tight', dpi=150)

plt.show()
